# %%
# !pip install ultralytics
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 881.7/881.7 kB 18.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.4/80.4 kB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 5.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="ynUrra5PEpc1NHQvUnoQ")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to football-players-detection-1 in yolov5pytorch:: 100%|██████████| 1338/1338 [00:00<00:00, 2481.39it/s]

# %%
import shutil

# %%
shutil.move("/content/football-players-detection-1/valid","/content/football-players-detection-1/football-players-detection-1/valid")
shutil.move("/content/football-players-detection-1/test","/content/football-players-detection-1/football-players-detection-1/test")
shutil.move("/content/football-players-detection-1/train","/content/football-players-detection-1/football-players-detection-1/train")
# Out:
# '/content/football-players-detection-1/football-players-detection-1/train'

# %%
# !yolo task=detect mode=train data={dataset.location}/data.yaml model=yolov5l.pt epochs =100 imgsz=640
# Out:
# PRO TIP 💡 Replace 'model=yolov5l.pt' with new 'model=yolov5lu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# ...
# 100% 102M/102M [00:00<00:00, 129MB/s]
# Ultralytics 8.3.4 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
